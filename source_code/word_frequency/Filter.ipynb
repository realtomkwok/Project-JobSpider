# %%
import numpy
import pandas as pd
import jieba
import jieba.analyse
import codecs

# %%
filePath = filePath = '../../data/data_sheets/processed/by_language/' + 'C#' + '.xlsx'
df = pd.read_excel(filePath, header=0, encoding='utf-8', dtype='str')
df
# Out:
#                            position  \
# 0                          工程图绘图实习生
# 1               技术咨询助理工程师（2020届实习岗）
# 2                         C#高级研发工程师
# 3                     .net开发工程师（广州）
# 4                            C#研发经理
# 5                         C#软件开发实习生
# 6                    自动化测试开发实习生（C#）
# 7                            C#开发实习
# 8                  ASP.net C# 软件工程师
# 9         c++ c# QT编程开发程序实习生.优者转正加薪
# 10                         C#工程师实习生
# 11                        C#软件开发实习生
# 12                        C#软件开发实习生
# 13                           C# 工程师
# 14                 【2020届实习】C#开发工程师
# 15           C#开发实习生（TDM/SCADA系统平台）
# 16                         软件开发 实习生
# 17                           信息化实习生
# 18                      java技术实习应届生
# 19                        实习生java方向
# 20                         U3D开发实习生
# 21                        c#软件开发实习生
# 22                        .net开发实习生
# 23                            开发工程师
# 24                        .net开发工程师
# 25                        .NET开发工程师
# 26                            软件实习生
# 27                          c#开发工程师
# 28                          c#开发工程师
# 29                        C#软件开发实习生
# ...                             ...
# 6612  Technical Director Art 美术技术总监
# 6613                Java高级开发工程师（紧急）
# 6614                        赴日软件工程师
# 6615                         软件研发经理
# 6616                       机器视觉开发总监
# 6617                     运动控制软件研发经理
# 6618                     机器视觉软件研发经理
# 6619                Java高级开发工程师（紧急）
# 6620                        UE4技术总监
# 6621             赴日IT软件工程师 SE/PG/日语
# 6622                Java高级开发工程师（紧急）
# 6623                          测试工程师
# 6624               Sitecore技术总监（高薪）
# 6625                         资深美术TA
# 6626              .NET资深架构师:30k-45k
# 6627                技术经理（C#、Python）
# 6628            软件开发-Java/c#/python
# 6629             云开发-Java/c#/python
# 6630         SNG01-手机QQ移动端开发工程师（深圳）
# 6631                        游戏主程-C#
# 6632        高级windows客户端工程师（C++/C#）
# 6633                 高级程序员（C# .NET）
# 6634      高级后端开发工程师（Java、C#、python）
# 6635                        C#软件工程师
# 6636                    c#开发工程师(中级)
# 6637                      首席技术官 CTO
# 6638                          资深架构师
# 6639          crm合伙人 crm股东 crm开发工程师
# 6640                           引擎专家
# 6641                          自动化测试
#
#                                                 company city district  \
# 0                                          北京城建智控科技有限公司   北京      NaN
# 1                                        欧姆龙自动化(中国)有限公司   上海      NaN
# 2                                      君信联合数字科技(北京)有限公司   深圳      NaN
# 3                                   北京北大软件工程股份有限公司武汉分公司   广州      NaN
# 4                           北京海淀区盈创动力园区E座南厅\n\n\n点击查看地图   北京      海淀区
# 5                                          上海博弋信息科技有限公司   上海      徐汇区
# 6     上海市 浦东新区 西门子医疗器械有限公司\n                        ...   上海     浦东新区
# 7                                        上海上外网络教育发展有限公司   上海      虹口区
# 8                                        广州迈维自动识别技术有限公司   广州      天河区
# 9     广州黄埔区科学城科学大道33号视联科技园B座528\n                   ...   广州      黄浦区
# 10    广州番禺区大学城\n                                \n  ...   广州      番禺区
# 11                                         广州致捷信息科技有限公司   广州      天河区
# 12                                         上海博弋信息科技有限公司   上海      徐汇区
# 13                                        广州隆积士信息科技有限公司   广州      天河区
# 14                                    深圳市华阳国际工程设计股份有限公司   深圳      福田区
# 15                                         北京大禹汇智科技有限公司   北京      NaN
# 16                                 联合建管（北京）国际工程科技有限责任公司   北京      NaN
# 17                                         北京师范大学教育培训中心   北京      NaN
# 18                                        山东森盛隆环保科技有限公司   北京      NaN
# 19                                        山东森盛隆环保科技有限公司   北京      NaN
# 20                                       北京东方仿真软件技术有限公司   北京      NaN
# 21                                           上海镒链科技有限公司   上海      NaN
# 22                                         北京恒赢智航科技有限公司   上海      NaN
# 23                                塔塔信息技术(中国)股份有限公司上海分公司   上海      NaN
# 24                                         上海兆客信息系统有限公司   上海      NaN
# 25                                       优利(上海)信息技术有限公司   上海      NaN
# 26                                      深圳市理邦精密仪器股份有限公司   深圳      NaN
# 27                                       广东省电信规划设计院有限公司   广州      NaN
# 28                                        广州易热捷信息技术有限公司   广州      NaN
# 29                                          广州市热马科技有限公司   广州      NaN
# ...                                                 ...  ...      ...
# 6612                            Ubisoft Shanghai Studio   上海      NaN
# 6613                                    北京昂讯咨询有限公司上海分公司   上海      NaN
# 6614                                           阳光软件株式会社   深圳      NaN
# 6615                                       深圳中科飞测科技有限公司   深圳      NaN
# 6616                                   深圳市德富莱智能科技股份有限公司   深圳      NaN
# 6617                                        深圳市鸿年科技有限公司   深圳      NaN
# 6618                                        深圳市鸿年科技有限公司   深圳      NaN
# 6619                                    北京昂讯咨询有限公司上海分公司   深圳      NaN
# 6620                                       广州谷得网络科技有限公司   广州      NaN
# 6621                                         大连翼速科技有限公司   广州      NaN
# 6622                                    北京昂讯咨询有限公司上海分公司   广州      NaN
# 6623                                      深圳市元源华高科技有限公司   广州      NaN
# 6624                                       广州杰索信息技术有限公司   广州      NaN
# 6625                                  深圳市睿杰时代企业管理咨询有限公司   广州      NaN
# 6626                                       广州旋风网络科技有限公司   广州      NaN
# 6627                                     布塔智联科技（北京）有限公司   北京     石景山区
# 6628                 上海市浦东新区哥白尼路与李冰路交叉口430号\n\n\n点击查看地图   上海     浦东新区
# 6629  上海市 浦东新区 哥白尼路与李冰路交叉口 430号\n                   ...   上海     浦东新区
# 6630  深圳南山区腾讯大厦\n                                \n ...   深圳      南山区
# 6631                                       北京小米科技有限责任公司   北京      海淀区
# 6632                                      北京外教易教育科技有限公司   北京      海淀区
# 6633                                     北京九思易自动化软件有限公司   北京      海淀区
# 6634                                   思特沃克软件技术（成都）有限公司   上海      长宁区
# 6635                                           锦珂国际有限公司   上海    闵行区
# 6636                                       北京中科恒硕科技有限公司   北京      NaN
# 6637                                     中智上海经济技术合作有限公司   上海      NaN
# 6638                                     中智上海经济技术合作有限公司   上海      NaN
# 6639                                       北京华琪软通技术有限公司   北京    海淀区
# 6640                                       上海巨人网络科技有限公司   上海      NaN
# 6641                                 深圳市德科信息技术有限公司广州分公司   广州      NaN
#
#      diploma_requirement wage_min wage_max wage_range experience  \
# 0                     大专        1        2      1千-2千       经验不限
# 1                     本科        1        2      1千-2千        无经验
# 2                     本科        1        2      1千-2千       1-3年
# 3                     本科        1        2      1千-2千       3-5年
# 4                     本科        2        3       2-3K      5-10年
# 5                     本科        2        4       2-4K       经验不限
# 6                     硕士        2        3       2-3K        应届生
# 7                     本科        2        4       2-4K        应届生
# 8                     不限        2        4       2-4K        应届生
# 9                     大专        2        4       2-4K       经验不限
# 10                    本科        2        3       2-3K       经验不限
# 11                    本科        2        4       2-4K        应届生
# 12                    本科        2        4      2k-4k         不限
# 13                    不限        2        4      2k-4k      应届毕业生
# 14                    本科        2        3      2k-3k      应届毕业生
# 15                    本科        2        3      2千-3千       经验不限
# 16                    本科        2        4      2千-4千        无经验
# 17                    本科        2        4      2千-4千        无经验
# 18                    大专        2        4      2千-4千       经验不限
# 19                    大专        2        4      2千-4千       经验不限
# 20                    大专        2        4      2千-4千        无经验
# 21                    本科        2        4      2千-4千       经验不限
# 22                    本科        2        4      2千-4千        无经验
# 23                    本科        2        4      2千-4千        无经验
# 24                    本科        2        4      2千-4千       经验不限
# 25                    本科        2        4      2千-4千        无经验
# 26                    不限        2        4      2千-4千       经验不限
# 27                    本科        2        3      2千-3千        无经验
# 28                    本科        2        4      2千-4千        无经验
# 29                    大专        2        4      2千-4千       经验不限
# ...                  ...      ...      ...        ...        ...
# 6612                  不限       30       50      3万-5万       经验不限
# 6613                  本科       30       50      3万-5万      5-10年
# 6614                  大专       30       60      3万-6万       经验不限
# 6615                  本科       30       50      3万-5万      5-10年
# 6616                  本科       30       50      3万-5万      10年以上
# 6617                  本科       30       60      3万-6万       经验不限
# 6618                  本科       30       60      3万-6万       经验不限
# 6619                  本科       30       50      3万-5万      5-10年
# 6620                  不限       30       50      3万-5万      5-10年
# 6621                  本科       30       50      3万-5万       1-3年
# 6622                  本科       30       50      3万-5万      5-10年
# 6623                  大专       30       50      3万-5万       经验不限
# 6624                  本科       30       35    3万-3.5万       3-5年
# 6625                  本科       30       50      3万-5万       3-5年
# 6626                  本科       30       50      3万-5万       经验不限
# 6627                  硕士       30       40     30-40K      5-10年
# 6628                  本科       30       50     30-50K      5-10年
# 6629                  本科       30       45     30-45K      5-10年
# 6630                  本科       30       31     30-31K       3-5年
# 6631                  本科       30       40    30k-40k      5-10年
# 6632                  大专       30       40    30k-40k      5-10年
# 6633                  本科       30       50    30k-50k      5-10年
# 6634                  不限       30       50    30k-50k      5-10年
# 6635                本科         33       42   40-50万/年         1年
# 6636                  本科       35       50    3.5万-5万      5-10年
# 6637                  硕士       40       60      4万-6万      5-10年
# 6638                  本科       40       58    4万-5.8万      5-10年
# 6639                大专         50       70     5-7万/月       3-4年
# 6640                  本科       50       70      5万-7万      5-10年
# 6641                  本科       70      100     7万-10万       3-5年
#
#                                       industry  \
# 0     IT服务(系统/数据/维护),计算机硬件,计算机软件,电子技术/半导体/集成电路
# 1                     仪器仪表及工业自动化,电子技术/半导体/集成电路
# 2                                  计算机软件,跨领域经营
# 3                                        计算机软件
# 4                                         医疗健康
# 5                                         信息安全
# 6                                         医疗健康
# 7                                          互联网
# 8                                        计算机软件
# 9                                        计算机软件
# 10                                    文化/体育/娱乐
# 11                                       计算机软件
# 12                                   信息安全,数据服务
# 13                                   企业服务,数据服务
# 14                                          其他
# 15             计算机软件,仪器仪表及工业自动化,IT服务(系统/数据/维护)
# 16                                房地产/建筑/建材/工程
# 17                                    教育/培训/院校
# 18                     互联网/电子商务,IT服务(系统/数据/维护)
# 19                     互联网/电子商务,IT服务(系统/数据/维护)
# 20      计算机软件,互联网/电子商务,IT服务(系统/数据/维护),石油/石化/化工
# 21                           计算机软件,基金/证券/期货/投资
# 22               计算机软件,IT服务(系统/数据/维护),互联网/电子商务
# 23           农/林/牧/渔,IT服务(系统/数据/维护),计算机软件,外包服务
# 24               计算机软件,IT服务(系统/数据/维护),互联网/电子商务
# 25         计算机软件,IT服务(系统/数据/维护),互联网/电子商务,计算机硬件
# 26                                     医疗设备/器械
# 27                     通信/电信运营、增值服务,通信/电信/网络设备
# 28       基金/证券/期货/投资,计算机软件,互联网/电子商务,通信/电信/网络设备
# 29       通信/电信/网络设备,计算机软件,计算机硬件,IT服务(系统/数据/维护)
# ...                                        ...
# 6612        网络游戏,计算机软件,IT服务(系统/数据/维护),互联网/电子商务
# 6613        互联网/电子商务,计算机软件,IT服务(系统/数据/维护),网络游戏
# 6614                                     计算机软件
# 6615   仪器仪表及工业自动化,电子技术/半导体/集成电路,检验/检测/认证,学术/科研
# 6616       仪器仪表及工业自动化,大型设备/机电设备/重工业,仪器仪表及工业自动化
# 6617                       计算机软件,电子技术/半导体/集成电路
# 6618                       计算机软件,电子技术/半导体/集成电路
# 6619        互联网/电子商务,计算机软件,IT服务(系统/数据/维护),网络游戏
# 6620    计算机软件,网络游戏,通信/电信运营、增值服务,IT服务(系统/数据/维护)
# 6621                               计算机软件,计算机软件
# 6622        互联网/电子商务,计算机软件,IT服务(系统/数据/维护),网络游戏
# 6623                                      网络游戏
# 6624                      计算机软件,IT服务(系统/数据/维护)
# 6625                      专业服务/咨询(财会/法律/人力资源等)
# 6626    互联网/电子商务,互联网/电子商务,计算机软件,IT服务(系统/数据/维护)
# 6627                                     计算机软件
# 6628                                     计算机软件
# 6629                                     计算机软件
# 6630                                       互联网
# 6631                                        硬件
# 6632                                        教育
# 6633                                        其他
# 6634                                      企业服务
# 6635                        多元化业务集团公司 机械/设备/重工
# 6636                            IT服务(系统/数据/维护)
# 6637                      专业服务/咨询(财会/法律/人力资源等)
# 6638                      专业服务/咨询(财会/法律/人力资源等)
# 6639                        通信/电信运营、增值服务 计算机软件
# 6640                             网络游戏,互联网/电子商务
# 6641                      计算机软件,IT服务(系统/数据/维护)
#
#                                                 welfare  \
# 0                                                   NaN
# 1                                      职位亮点免费班车大牛带队免费停车
# 2                            职位亮点绩效奖金周末双休项目奖金定期团建餐补五险一金
# 3                     职位亮点14薪周末双休五险一金绩效奖金餐补带薪年假定期体检员工旅游
# 4     \n五险一金,补充医疗保险,定期体检,加班补助,年终奖,带薪年假,员工旅游,餐补,通讯补贴,...
# 5     \n                                    股票期权,扁平管...
# 6                                                   NaN
# 7     \n                                    五险一金,带薪年...
# 8     \n                                    年度旅游,智能硬...
# 9                                                   NaN
# 10                                                  NaN
# 11    \n                                    五险一金,带薪年...
# 12                                  做五休二,国外旅游,五险一金,晋升机会
# 13                                              领导好,氛围好
# 14                                    实习补贴、免费住宿、餐补、专业导师
# 15                     职位亮点五险一金餐补通讯补助带薪年假补充医疗保险周末双休项目奖金
# 16                                               职位亮点餐补
# 17                                         职位亮点周末双休大牛带队
# 18                              职位亮点五险一金年底双薪绩效奖金周末双休不加班
# 19                              职位亮点五险一金年底双薪绩效奖金周末双休不加班
# 20                                   职位亮点弹性工作员工旅游节日福利包吃
# 21                                                  NaN
# 22                       职位亮点周末双休五险一金带薪年假补充医疗保险绩效奖金免费班车
# 23                   职位亮点弹性工作周末双休带薪年假年底双薪定期体检补充医疗保险五险一金
# 24                                               职位亮点餐补
# 25                                                  NaN
# 26                       职位亮点五险一金绩效奖金包住餐补房补带薪年假免费班车高温补贴
# 27                        职位亮点年底双薪绩效奖金高温补贴周末双休健身俱乐部定期体检
# 28                               职位亮点五险一金交通补助餐补节日福利定期体检
# 29                       职位亮点节日福利不加班五险一金包吃包住带薪年假全勤奖年底双薪
# ...                                                 ...
# 6612                                                NaN
# 6613                 职位亮点五险一金年底双薪年终分红绩效奖金全勤奖交通补助14薪周末双休
# 6614               职位亮点绩效奖金年终分红交通补助带薪年假定期体检节日福利周末双休定期团建
# 6615                   职位亮点五险一金年底双薪绩效奖金餐补带薪年假免费班车包住定期体检
# 6616               职位亮点五险一金年底双薪带薪年假创业公司弹性工作员工旅游节日福利免费停车
# 6617                                           职位亮点五险一金
# 6618                                           职位亮点五险一金
# 6619                 职位亮点五险一金年底双薪年终分红绩效奖金全勤奖交通补助14薪周末双休
# 6620               职位亮点五险一金绩效奖金餐补带薪年假补充医疗保险定期体检节日福利周末双休
# 6621               职位亮点周末双休绩效奖金加班补助带薪年假交通补助定期体检员工旅游年终分红
# 6622                 职位亮点五险一金年底双薪年终分红绩效奖金全勤奖交通补助14薪周末双休
# 6623                   职位亮点年底双薪包住包吃带薪年假加班补助节日福利项目奖金大牛带队
# 6624              职位亮点绩效奖金年终分红每年多次调薪节日福利弹性工作不加班五险一金员工旅游
# 6625                       职位亮点五险一金年底双薪绩效奖金员工旅游节日福利弹性工作
# 6626                     职位亮点五险一金加班补助弹性工作绩效奖金餐补周末双休节日福利
# 6627    \n扁平管理,移动互联网,公司氛围好,带薪年假,免费零食,领导nice,美女如云,年度旅游\n
# 6628    \n五险一金,补充医疗保险,定期体检,年终奖,带薪年假,员工旅游,餐补,交通补助,节日福利\n
# 6629  \n                                    五险一金,补充医...
# 6630  \n                                    补充医疗保险,定...
# 6631                                  重点项目，优秀的团队伙伴，薪酬领先
# 6632                                    福利好 氛围好 团队好 平台好
# 6633                               五险一金,定期体检,优秀团队,最多5个字
# 6634                                  外企背景 追求技术卓越 扁平化管理
# 6635  做五休二 带薪年假 五险一金 绩效奖金 节日福利 高温补贴 加班补贴 定期体检 年终奖金 专业培训
# 6636                               职位亮点五险一金周末双休带薪年假免费班车
# 6637                                                NaN
# 6638                                                NaN
# 6639                      五险一金 员工旅游 餐饮补贴 通讯补贴 绩效奖金 年终奖金
# 6640               职位亮点五险一金绩效奖金年终分红带薪年假定期体检免费班车员工旅游节日福利
# 6641              职位亮点周末双休六险一金带薪年假年前年终奖弹性工作包吃试用期全额全额公积金
#
#                                             description        size  \
# 0     职位描述岗位职责：1. 负责协助软件或项目的需求分析工作和设计工作；2. 根据开发进度和任务...    100-499人
# 1     职位描述1、执行客户服务中心操作流程，接听客户咨询电话；  2、解决客户在使用公司产品时遇到...  1000-9999人
# 2     职位描述岗位职责��1、配合产品经理完成项目开发任务2、掌握基本的用户业务、持续跟踪掌握新技...      20-99人
# 3     职位描述（一）岗位职责1、 参与项目需求调研、分析与方案设计；2、 承担项目开发任务，按计划...    100-499人
# 4     该职位是一个技术+管理类职位，不适合单纯技术专家，需要把握团队，理解产品，结果负责。技能要求...    100-499人
# 5     职位信息描述1.     企业管理软件开发、安全应用软件开发等；2.     根据开发进度和...      20-99人
# 6     职位职责： SSME currently looking for intern who is...  1000-9999人
# 7                                             协助c#项目的开发      20-99人
# 8     岗位职责：1．对进销存系统项目开发和支持；2．根据设计进行实际的代码编写工作，协助其它同事共...      20-99人
# 9     不限工作经验，只要你基础好，人勤奋好学，诚实守信的，技术牛B就可来谈大家认识一下。主要负责模...       0-20人
# 10    jtcloud工作室实习C#工程师招募待遇薪酬面议要求：1，本科或以上学历，有相关项目经验，...      20-99人
# 11    1、参与前后台代码的编写；2、相关缺陷的修复。任职要求：1、全日制本科大四或硕士研二在校生，...      20-99人
# 12                                       信息安全大数据C#/.NET      15-50人
# 13                                WinformC#/.NETWindows       少于15人
# 14                                              C#/.NET     2000人以上
# 15    职位描述技能要求：C#/.NETWpfWinform期望：1.  桌面应用软件和工具类软件开...      20-99人
# 16    职位描述职位描述：1. 能够熟练应用vs2015做asp.net开发； 2. c#语言要求熟...      20-99人
# 17    职位描述技能要求：C#Html+CSS+JS一、岗位职责：1、负责公司内部网站系统辅助开发及...    100-499人
# 18    职位描述技能要求：CC++Java任职要求：1、应、往届计算机、信息、软件、电子技术、自动化...    500-999人
# 19    职位描述技能要求：CC++Java1：大专以上学历，应往届计算机专业毕业生，对编程感兴趣，有...    500-999人
# 20    职位描述技能要求：U3D工作职责：1.使用unity3d进行虚拟仿真化工、制药、分析、环境软...    100-499人
# 21    职位描述  上海镒链金融科技公司专注于风险管理、衍生品估值、金融数据、前台交易等核心技术，是...      20-99人
# 22    职位描述岗位职责 1、技术人员职位，在开发经理的领导和监督下定期完成量化的工作要求； 2、学...    100-499人
# 23    职位描述岗位职责：1.系统维护和新功能的开发2.银行系统的问题分析和解决方案3.新系统的测试...    10000人以上
# 24    职位描述技能要求：MVCC#/.NET岗位职责：1、熟悉.NET多层开发和分布式计算体系结构...      20-99人
# 25    职位描述技能要求：C#/.NETCC++招C#/.NET开发工程师 实习生（2020届毕业生...    500-999人
# 26    职位描述所属部门：研发系统 工作地点：深圳市坪山区 任职要求： （实习3-6个月）1.生物医...  1000-9999人
# 27    职位描述技能要求：C#/.NETJavaPython岗位职责：1、 协助上级进行项目模块设计...  1000-9999人
# 28    职位描述岗位描述： 参与OSS和IMS系统开发需求研发工作职位要求：1、本科以上学历， 1年...    100-499人
# 29    职位描述1、参与前后台代码的编写；2、相关缺陷的修复；任职要求：1、专科以上学历，专业不限；...      20-99人
# ...                                                 ...         ...
# 6612  职位描述SummaryThe incumbent will determine, prepa...    500-999人
# 6613  职位描述技能要求：分布式Java1、 主导业务、技术改造等类项目的系统分析、设计工作，负责平...      20-99人
# 6614  职位描述公司名称：SUNNYSOFT阳光软件株式会社直招岗位：赴日软件工程师工作地点：东京及...      20-99人
# 6615  职位描述岗位职责：1.负责本部门的具体工作分配、进度跟进、绩效跟踪、内部协调、资源整合等工作...    100-499人
# 6616  职位描述岗位职责：1. 负责公司自动化设备，非标设备运动控制系统的开发及改进；2. 负责机器...    500-999人
# 6617  职位描述岗位职责：1.参与客户方案（或产品）需求洽谈，促成公司方案（或产品）销售；2.筛选或...      20-99人
# 6618  职位描述岗位职责：1、参与客户方案（或产品）需求洽谈，促成公司方案（或产品）销售；2、熟练掌...      20-99人
# 6619  职位描述技能要求：分布式Java1、 主导业务、技术改造等类项目的系统分析、设计工作，负责平...      20-99人
# 6620  职位描述技能要求：技术管理虚幻4VR游戏岗位职责：1、使用unreal4引擎进行游戏客户端模...    100-499人
# 6621  职位描述1.专科以上学历，计算机相关专业或普通高度高校毕业，性别不限；2.职历经验：①管理职...      20-99人
# 6622  职位描述技能要求：分布式Java1、 主导业务、技术改造等类项目的系统分析、设计工作，负责平...      20-99人
# 6623  职位描述技能要求：测试Android测试IOS测试Web测试Windows测试产品测试1、参...    500-999人
# 6624  职位描述技能要求：项目管理技术管理解决方案高级技术管理部门管理系统架构岗位职责:1、负责设计...      20-99人
# 6625  职位描述岗位描述1.研究游戏项目中美术内容制作的各项工具使用。2.熟悉并研究游戏引擎的各项功...      20-99人
# 6626  职位描述技能要求：高并发Redis高负载高可用性系统1.有一年以上的asp.net core...      20-99人
# 6627  岗位描述：1、参与公司战略讨论，根据公司发展需求制定技术战略规划，制定技术部团队整体运营发展...      20-99人
# 6628  HoneywellisaFortune100companywithglobalsalessu...    10000人以上
# 6629  Honeywell is a Fortune 100 company with global...    10000人以上
# 6630  工作职责：负责QQ移动端应用开发；探索QQ跨平台的软件开发和新技术研究；负责QQ跨平台产品的...    10000人以上
# 6631                                         C++C#/.NET     2000人以上
# 6632                                    C++音视频全栈C#/.NET     50-150人
# 6633                                          后端C#/.NET     50-150人
# 6634                                                 后端     2000人以上
# 6635  工作职责： 1.负责公司交易软件单独模块开发的详细设计； 2.负责软件的编码、代码审查、单元...    150-500人
# 6636  职位描述技能要求：C#职位职责：1、完成软件系统代码的实现，编写代码注释和开发文档；2、进行...      20-99人
# 6637  职位描述职位描述：1、全面负责公司大数据技术规划、管理，数据平台搭建、数据模型开发、数据应用...  1000-9999人
# 6638  职位描述岗位职责:1、  根据产品规划进行业务需求系统分析，提出技术方案和系统设计及概要设计...  1000-9999人
# 6639  我们有2家公司：北京智云广通技术有限公司和北京华琪软通技术有限公司，是1999年成立的，20...       少于50人
# 6640  职位描述岗位职责:1、负责多人实时竞技游戏项目的底层技术框架搭建；2、负责优化开发团队的编码...  1000-9999人
# 6641  职位描述1、本科及以上学历，计算机相关专业毕业；2、掌握至少一种开发语言（如Java、C#）...  1000-9999人
#
#      company_type
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# ...           ...
# 6612          NaN
# 6613          NaN
# 6614          NaN
# 6615          NaN
# 6616          NaN
# 6617          NaN
# 6618          NaN
# 6619          NaN
# 6620          NaN
# 6621          NaN
# 6622          NaN
# 6623          NaN
# 6624          NaN
# 6625          NaN
# 6626          NaN
# 6627          NaN
# 6628          NaN
# 6629          NaN
# 6630          NaN
# 6631          NaN
# 6632          NaN
# 6633          NaN
# 6634          NaN
# 6635      外资（非欧美）
# 6636          NaN
# 6637          NaN
# 6638          NaN
# 6639         民营公司
# 6640          NaN
# 6641          NaN
#
# [6642 rows x 14 columns]

# %%
indDf = df[['industry']]
indDf
# Out:
#                                       industry
# 0     IT服务(系统/数据/维护),计算机硬件,计算机软件,电子技术/半导体/集成电路
# 1                     仪器仪表及工业自动化,电子技术/半导体/集成电路
# 2                                  计算机软件,跨领域经营
# 3                                        计算机软件
# 4                                         医疗健康
# 5                                         信息安全
# 6                                         医疗健康
# 7                                          互联网
# 8                                        计算机软件
# 9                                        计算机软件
# 10                                    文化/体育/娱乐
# 11                                       计算机软件
# 12                                   信息安全,数据服务
# 13                                   企业服务,数据服务
# 14                                          其他
# 15             计算机软件,仪器仪表及工业自动化,IT服务(系统/数据/维护)
# 16                                房地产/建筑/建材/工程
# 17                                    教育/培训/院校
# 18                     互联网/电子商务,IT服务(系统/数据/维护)
# 19                     互联网/电子商务,IT服务(系统/数据/维护)
# 20      计算机软件,互联网/电子商务,IT服务(系统/数据/维护),石油/石化/化工
# 21                           计算机软件,基金/证券/期货/投资
# 22               计算机软件,IT服务(系统/数据/维护),互联网/电子商务
# 23           农/林/牧/渔,IT服务(系统/数据/维护),计算机软件,外包服务
# 24               计算机软件,IT服务(系统/数据/维护),互联网/电子商务
# 25         计算机软件,IT服务(系统/数据/维护),互联网/电子商务,计算机硬件
# 26                                     医疗设备/器械
# 27                     通信/电信运营、增值服务,通信/电信/网络设备
# 28       基金/证券/期货/投资,计算机软件,互联网/电子商务,通信/电信/网络设备
# 29       通信/电信/网络设备,计算机软件,计算机硬件,IT服务(系统/数据/维护)
# ...                                        ...
# 6612        网络游戏,计算机软件,IT服务(系统/数据/维护),互联网/电子商务
# 6613        互联网/电子商务,计算机软件,IT服务(系统/数据/维护),网络游戏
# 6614                                     计算机软件
# 6615   仪器仪表及工业自动化,电子技术/半导体/集成电路,检验/检测/认证,学术/科研
# 6616       仪器仪表及工业自动化,大型设备/机电设备/重工业,仪器仪表及工业自动化
# 6617                       计算机软件,电子技术/半导体/集成电路
# 6618                       计算机软件,电子技术/半导体/集成电路
# 6619        互联网/电子商务,计算机软件,IT服务(系统/数据/维护),网络游戏
# 6620    计算机软件,网络游戏,通信/电信运营、增值服务,IT服务(系统/数据/维护)
# 6621                               计算机软件,计算机软件
# 6622        互联网/电子商务,计算机软件,IT服务(系统/数据/维护),网络游戏
# 6623                                      网络游戏
# 6624                      计算机软件,IT服务(系统/数据/维护)
# 6625                      专业服务/咨询(财会/法律/人力资源等)
# 6626    互联网/电子商务,互联网/电子商务,计算机软件,IT服务(系统/数据/维护)
# 6627                                     计算机软件
# 6628                                     计算机软件
# 6629                                     计算机软件
# 6630                                       互联网
# 6631                                        硬件
# 6632                                        教育
# 6633                                        其他
# 6634                                      企业服务
# 6635                        多元化业务集团公司 机械/设备/重工
# 6636                            IT服务(系统/数据/维护)
# 6637                      专业服务/咨询(财会/法律/人力资源等)
# 6638                      专业服务/咨询(财会/法律/人力资源等)
# 6639                        通信/电信运营、增值服务 计算机软件
# 6640                             网络游戏,互联网/电子商务
# 6641                      计算机软件,IT服务(系统/数据/维护)
#
# [6642 rows x 1 columns]

# %%
expDf = indDf.groupby('industry').size().reset_index(name='counts')
expDf.to_excel('expDf.xlsx')

# %%
rows = pd.read_excel('expDf.xlsx', encoding='utf-8', dtype='str')
rows
# Out:
#      Unnamed: 0                                           industry counts
# 0             0                          IT|通信|电子|互联网,IT|通信|电子|互联网      1
# 1             1                        IT|通信|电子|互联网,IT服务(系统/数据/维护)      2
# 2             2            IT|通信|电子|互联网,计算机软件,电气/电力/水利,能源/矿产/采掘/冶炼      1
# 3             3                                     IT服务(系统/数据/维护)     56
# 4             4                      IT服务(系统/数据/维护),IT服务(系统/数据/维护)      5
# 5             5    IT服务(系统/数据/维护),IT服务(系统/数据/维护),基金/证券/期货/投资,计算机软件      1
# 6             6             IT服务(系统/数据/维护),IT服务(系统/数据/维护),娱乐/体育/休闲      2
# 7             7  IT服务(系统/数据/维护),IT服务(系统/数据/维护),计算机硬件,专业服务/咨询(财会...      2
# 8             8       IT服务(系统/数据/维护),IT服务(系统/数据/维护),计算机硬件,互联网/电子商务      1
# 9             9          IT服务(系统/数据/维护),IT服务(系统/数据/维护),计算机硬件,计算机软件      1
# 10           10                IT服务(系统/数据/维护),IT服务(系统/数据/维护),计算机软件      1
# 11           11       IT服务(系统/数据/维护),IT服务(系统/数据/维护),计算机软件,互联网/电子商务      2
# 12           12           IT服务(系统/数据/维护),IT服务(系统/数据/维护),计算机软件,外包服务      1
# 13           13                IT服务(系统/数据/维护),专业服务/咨询(财会/法律/人力资源等)      6
# 14           14                IT服务(系统/数据/维护),中介服务,汽车/摩托车,互联网/电子商务      1
# 15           15                            IT服务(系统/数据/维护),互联网/电子商务      1
# 16           16       IT服务(系统/数据/维护),互联网/电子商务,IT服务(系统/数据/维护),计算机软件      2
# 17           17           IT服务(系统/数据/维护),互联网/电子商务,仪器仪表及工业自动化,计算机软件      1
# 18           18                   IT服务(系统/数据/维护),互联网/电子商务,其他,计算机软件      3
# 19           19  IT服务(系统/数据/维护),互联网/电子商务,教育/培训/院校,医疗/护理/美容/保健/卫生服务      2
# 20           20             IT服务(系统/数据/维护),互联网/电子商务,检验/检测/认证,计算机软件      1
# 21           21        IT服务(系统/数据/维护),互联网/电子商务,电子技术/半导体/集成电路,计算机软件      1
# 22           22                       IT服务(系统/数据/维护),互联网/电子商务,网络游戏      1
# 23           23         IT服务(系统/数据/维护),互联网/电子商务,计算机硬件,通信/电信运营、增值服务      1
# 24           24                      IT服务(系统/数据/维护),互联网/电子商务,计算机软件     11
# 25           25       IT服务(系统/数据/维护),互联网/电子商务,计算机软件,IT服务(系统/数据/维护)      2
# 26           26  IT服务(系统/数据/维护),互联网/电子商务,计算机软件,专业服务/咨询(财会/法律/人力...      1
# 27           27          IT服务(系统/数据/维护),互联网/电子商务,计算机软件,基金/证券/期货/投资      1
# 28           28                IT服务(系统/数据/维护),互联网/电子商务,计算机软件,计算机硬件      7
# 29           29           IT服务(系统/数据/维护),互联网/电子商务,计算机软件,通信/电信/网络设备      3
# ...         ...                                                ...    ...
# 1503       1503                                        酒店/旅游 航天/航空      1
# 1504       1504                                        酒店/旅游 计算机软件      1
# 1505       1505                                          酒店/旅游 餐饮业      1
# 1506       1506                                              酒店/餐饮      1
# 1507       1507                                 酒店/餐饮,IT|通信|电子|互联网      1
# 1508       1508   酒店/餐饮,IT服务(系统/数据/维护),广告/会展/公关,快速消费品（食品/饮料/烟酒/日化）      8
# 1509       1509                                        酒店/餐饮,旅游/度假      1
# 1510       1510                                                 金融      6
# 1511       1511                                           金融,医疗丨健康      1
# 1512       1512                                            金融,数据服务      2
# 1513       1513                                           金融,移动互联网      3
# 1514       1514                                           金融/投资/证券      3
# 1515       1515                          金融/投资/证券 专业服务(咨询、人力资源、财会)      1
# 1516       1516                                  金融/投资/证券 互联网/电子商务      5
# 1517       1517                         金融/投资/证券 计算机服务(系统、数据服务、维修)      1
# 1518       1518                                     金融/投资/证券 计算机软件      3
# 1519       1519                                        金融/投资/证券 银行      1
# 1520       1520                                    金融业,基金/证券/期货/投资      1
# 1521       1521                                          金融业,计算机软件      1
# 1522       1522                                                 银行      2
# 1523       1523                                   银行,互联网/电子商务,中介服务      1
# 1524       1524                                              零售/批发      5
# 1525       1525                          零售/批发,办公用品及设备,计算机硬件,计算机软件      1
# 1526       1526                             零售/批发,医疗设备/器械,零售/批发,其他      1
# 1527       1527  零售/批发,快速消费品（食品/饮料/烟酒/日化）,零售/批发,耐用消费品（服饰/纺织/皮革/...      1
# 1528       1528                        零售/批发,耐用消费品（服饰/纺织/皮革/家具/家电）      5
# 1529       1529  零售/批发,耐用消费品（服饰/纺织/皮革/家具/家电）,互联网/电子商务,快速消费品（食品/...      1
# 1530       1530                                           音乐/视频/阅读      4
# 1531       1531                                                 餐饮      1
# 1532       1532                                                餐饮业      1
#
# [1533 rows x 3 columns]

# %%
segments = []
for index, row in rows.iterrows():
    content = row[1]
    words = jieba.analyse.textrank(content, topK=20, withWeight=False, allowPOS=('ns', 'n', 'vn', 'v'))
    splitedStr = ''

    for word in words:
        segments.append({'keyword': word, 'count': 1})
        splitedStr += word + ' '

# %%
dfSg = pd.DataFrame(segments)
dfSg
# Out:
#       count keyword
# 0         1      电子
# 1         1     互联网
# 2         1      服务
# 3         1      系统
# 4         1      数据
# 5         1     互联网
# 6         1      维护
# 7         1      电子
# 8         1   计算机软件
# 9         1      矿产
# 10        1      能源
# 11        1      电气
# 12        1      电力
# 13        1      水利
# 14        1      采掘
# 15        1     互联网
# 16        1      电子
# 17        1      冶炼
# 18        1      系统
# 19        1      数据
# 20        1      维护
# 21        1      服务
# 22        1      系统
# 23        1      数据
# 24        1      维护
# 25        1      服务
# 26        1      期货
# 27        1      维护
# 28        1      系统
# 29        1      数据
# ...     ...     ...
# 9637      1      批发
# 9638      1      饮料
# 9639      1      食品
# 9640      1      皮革
# 9641      1      服饰
# 9642      1      烟酒
# 9643      1      家具
# 9644      1      零售
# 9645      1      纺织
# 9646      1     消费品
# 9647      1      皮革
# 9648      1      服饰
# 9649      1      批发
# 9650      1      家具
# 9651      1      零售
# 9652      1     消费品
# 9653      1      纺织
# 9654      1      饮料
# 9655      1      食品
# 9656      1      皮革
# 9657      1      服饰
# 9658      1    电子商务
# 9659      1      批发
# 9660      1      烟酒
# 9661      1      家具
# 9662      1      零售
# 9663      1     互联网
# 9664      1      音乐
# 9665      1      阅读
# 9666      1      视频
#
# [9667 rows x 2 columns]

# %%
dfWord = dfSg.groupby('keyword')['count'].sum()
fileName = 'C#'
dfWord.to_excel('outputs/{}_keywords.xlsx'.format(fileName), encoding='utf-8')

# %%
def keywordFilter(language):
    filePath = '../../data/data_sheets/processed/by_language/' + language + '.xlsx'
    #Import the Excel sheet and create a dataframe
    df = pd.read_excel(filePath, header=0, encoding='utf-8', dtype='str')
    #Create a dataframe for column 'industry'
    indDf = df[['industry']]
    #Create a temporate file to store these data for the next step
    tempDf = indDf.groupby('industry').size().reset_index(name='counts')
    tempDf.to_excel('temp.xlsx')

    rows = pd.read_excel('temp.xlsx', encoding='utf-8', dtype='str')
    segments = []

    for index, row in rows.iterrows():
        content = row[1]
        words = jieba.analyse.textrank(content, topK=20, withWeight=False, allowPOS=('ns', 'n', 'vn', 'v'))
        splitedStr = ''

        for word in words:
            segments.append({'keyword': word, 'count': 1})
            splitedStr += word + ' '

    dfSg = pd.DataFrame(segments)
    dfWord = dfSg.groupby('keyword')['count'].sum()
    dfWord.to_excel('outputs/{}_keywords.xlsx'.format(language), encoding='utf-8')
    print("Keywords of {} has been sucessfully analysed!".format(language))
    
languages = ['C#', 'C++', 'Java', 'HTML+CSS', 'JavaScript', 'PHP', 'Python', 'Ruby', 'Swift', 'TypeScript']
for language in languages:
    keywordFilter(language)
# Out:
# Keywords of C# has been sucessfully analysed!
# Keywords of C++ has been sucessfully analysed!
# Keywords of Java has been sucessfully analysed!
# Keywords of HTML+CSS has been sucessfully analysed!
# Keywords of JavaScript has been sucessfully analysed!
# Keywords of PHP has been sucessfully analysed!
# Keywords of Python has been sucessfully analysed!
# Keywords of Ruby has been sucessfully analysed!
# Keywords of Swift has been sucessfully analysed!
# Keywords of TypeScript has been sucessfully analysed!

# %%
htmlDf = pd.read_excel('../../data/data_sheets/processed/by_language/HTML+CSS.xlsx', encoding='utf-8', dtype=str)
testDf = htmlDf[['industry']]
testDf
# Out:
#                                      industry
# 0                              计算机软件 互联网/电子商务
# 1                              互联网/电子商务 计算机软件
# 2                通信/电信/网络设备 计算机服务(系统、数据服务、维修)
# 3                                       计算机软件
# 4                                贸易/进出口 批发/零售
# 5                              计算机软件 互联网/电子商务
# 6                              互联网/电子商务 计算机软件
# 7                  互联网/电子商务 计算机服务(系统、数据服务、维修)
# 8                                       计算机软件
# 9                     计算机服务(系统、数据服务、维修) 计算机软件
# 10                         贸易/进出口 家具/家电/玩具/礼品
# 11                                 计算机软件 网络游戏
# 12                         计算机软件 通信/电信运营、增值服务
# 13                       餐饮业 快速消费品(食品、饮料、化妆品)
# 14                                   互联网/电子商务
# 15                             计算机软件 教育/培训/院校
# 16                              批发/零售 制药/生物工程
# 17                          服装/纺织/皮革 互联网/电子商务
# 18                                      非营利组织
# 19                                         广告
# 20                                      计算机软件
# 21                           专业服务(咨询、人力资源、财会)
# 22                  教育/培训/院校 专业服务(咨询、人力资源、财会)
# 23                             互联网/电子商务 计算机软件
# 24                    计算机软件 计算机服务(系统、数据服务、维修)
# 25                                   互联网/电子商务
# 26                             建筑/建材/工程 计算机软件
# 27                                   互联网/电子商务
# 28                    计算机服务(系统、数据服务、维修) 计算机软件
# 29                    计算机软件 计算机服务(系统、数据服务、维修)
# ...                                       ...
# 4113                       职位亮点五险一金年底双薪餐补定期体检
# 4114         职位亮点绩效奖金全勤奖餐补带薪年假节日福利五险一金出国游周末双休
# 4115       职位亮点周末双休五险一金交通补助餐补通讯补助员工旅游节日福利定期体检
# 4116   职位亮点五险一金补充医疗保险定期体检节日福利带薪年假弹性工作员工旅游绩效奖金
# 4117        职位亮点五险一金绩效奖金带薪年假定期体检节日福利周末双休不加班餐补
# 4118                 职位亮点五险一金绩效奖金带薪年假节日福利员工旅游
# 4119  职位亮点高绩效奖金五险一金全额公积金工作居住证节日福利交通补助通讯补助带薪年假
# 4120           职位亮点五险一金绩效奖金加班补助全勤奖员工旅游节日福利不加班
# 4121                                 职位亮点五险一金
# 4122                                      NaN
# 4123           职位亮点绩效奖金带薪年假补充医疗保险定期体检节日福利五险一金
# 4124                   职位亮点五险一金员工旅游餐补带薪年假加班补助
# 4125               职位亮点每年多次调薪年终分红绩效奖金弹性工作交通补助
# 4126        职位亮点周末双休住房补贴绩效奖金年终分红交通补助包住餐补健身俱乐部
# 4127                                      NaN
# 4128   职位亮点绩效奖金五险一金年底双薪节日福利员工旅游定期体检带薪年假补充医疗保险
# 4129        职位亮点年底双薪绩效奖金全勤奖包吃带薪年假员工旅游高温补贴节日福利
# 4130     职位亮点五险一金加班补助员工旅游带薪年假年终分红绩效奖金定期团建节日福利
# 4131                   职位亮点五险一金周末双休餐补弹性工作带薪年假
# 4132                                      NaN
# 4133                     职位亮点创业公司年终分红股票期权五险一金
# 4134   职位亮点五险一金周末双休年底双薪绩效奖金免费班车节日福利每年多次调薪带薪年假
# 4135             职位亮点弹性工作带薪年假五险一金创业公司定期团建周末双休
# 4136       职位亮点五险一金绩效奖金带薪年假大牛带队公司重点项目不加班全勤奖餐补
# 4137   职位亮点周末双休弹性工作补充医疗保险五险一金绩效奖金年底双薪通讯补助定期体检
# 4138                                      NaN
# 4139           职位亮点五险一金年底双薪餐补带薪年假定期体检高温补贴节日福利
# 4140         职位亮点五险一金年底双薪绩效奖金带薪年假弹性工作员工旅游节日福利
# 4141      职位亮点五险一金带薪年假定期体检周末双休交通补助餐补通讯补助试用期全额
# 4142                     职位亮点五险一金绩效奖金弹性工作周末双休
#
# [4143 rows x 1 columns]
